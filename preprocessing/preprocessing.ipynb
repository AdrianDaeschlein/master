# %%
import os 
import pandas as pd
import numpy as np

# %% [markdown]
# Feature Engineering
# - Peak value
# - Peak-to-peak value
# - Amplitude
# - Energy
# - Frequency
# - Peak-to-peak
# - ARV: Average rectified value
# - Weighted-ARV:
# - FFT: Frequency spektrum, different frequency parts (maybe)
#
# Clustering
#
# Data Augmentation

# %% [markdown]
# # Feature Engineering

# %%
df_geophone = pd.read_csv('merged_geophone_falls.csv')
df_geophone.head()
# Out:
#   activity  fall_binary  distance_m  person_binary  weight floor  value_1  \
# 0      FCS            1           1              1    75.0     H       59
# 1      FCS            1           1              1    75.0     H      104
# 2      FCS            1           1              1    75.0     H      -11
# 3      FCS            1           1              1    75.0     H       16
# 4      FCS            1           1              1    75.0     H        5
#
#    value_2  value_3  value_4  ...  value_491  value_492  value_493  value_494  \
# 0      -38       10       43  ...         10         -8         -6          3
# 1      -49      137      -46  ...         -1        -15         -9          6
# 2       48      -13        8  ...        170       -107       -246         70
# 3      -11       22        4  ...          2         -8        -13          0
# 4      -11       -4        2  ...         36         12          2         13
#
#    value_495  value_496  value_497  value_498  value_499  value_500
# 0          6         -5         10         10        -12         -6
# 1         13          6          5          6         -4        -17
# 2        158        110        -52       -100         63         76
# 3         13          1         -1          4          4         -9
# 4          8          7          9        -33        -11        -11
#
# [5 rows x 506 columns]

# %%
def add_max_min_avg_p2p_columns(df):
    """
    Adds four columns representing the maximum, minimum, average,
    and peak-to-peak value of signal data in each row.

    Parameters:
    - df (pd.DataFrame): The DataFrame containing signal data.

    Returns:
    - pd.DataFrame: The DataFrame with the new 'max_value', 'min_value',
      'avg_value', and 'p2p_value' columns.
    """
    # Signal data starts from column index 6
    signal_columns = df.columns[6:]

    # Compute values
    df['max_value'] = df[signal_columns].max(axis=1)
    df['min_value'] = df[signal_columns].min(axis=1)
    df['avg_value'] = df[signal_columns].mean(axis=1)
    df['p2p_value'] = df['max_value'] - df['min_value']

    return df

# Example usage:
df_geophone = add_max_min_avg_p2p_columns(df_geophone)
df_geophone.head()
# Out:
#   activity  fall_binary  distance_m  person_binary  weight floor  value_1  \
# 0      FCS            1           1              1    75.0     H       59
# 1      FCS            1           1              1    75.0     H      104
# 2      FCS            1           1              1    75.0     H      -11
# 3      FCS            1           1              1    75.0     H       16
# 4      FCS            1           1              1    75.0     H        5
#
#    value_2  value_3  value_4  ...  value_495  value_496  value_497  value_498  \
# 0      -38       10       43  ...          6         -5         10         10
# 1      -49      137      -46  ...         13          6          5          6
# 2       48      -13        8  ...        158        110        -52       -100
# 3      -11       22        4  ...         13          1         -1          4
# 4      -11       -4        2  ...          8          7          9        -33
#
#    value_499  value_500  max_value  min_value  avg_value  p2p_value
# 0        -12         -6       3335      -2904    -12.574       6239
# 1         -4        -17       1794      -5425    -15.622       7219
# 2         63         76       8664      -4533     22.256      13197
# 3          4         -9       8603      -1911     19.398      10514
# 4        -11        -11       6241     -13943    -18.060      20184
#
# [5 rows x 510 columns]

# %% [markdown]
# ## Add peak value

# %%
def add_peak_column(df):
    """
    Adds a column representing the peak value (maximum absolute value) 
    of signal data in each row.

    Parameters:
    - df (pd.DataFrame): The DataFrame containing signal data.

    Returns:
    - pd.DataFrame: The DataFrame with the new 'peak_value' column.
    """
    # Signal data starts from column index 6
    signal_columns = df.columns[6:]

    # Compute peak value (max absolute value)
    df['peak_value'] = df[signal_columns].abs().max(axis=1)

    return df

# Example usage:
df_geophone = add_peak_column(df_geophone)
df_geophone.head()
# Out:
#   activity  fall_binary  distance_m  person_binary  weight floor  value_1  \
# 0      FCS            1           1              1    75.0     H       59
# 1      FCS            1           1              1    75.0     H      104
# 2      FCS            1           1              1    75.0     H      -11
# 3      FCS            1           1              1    75.0     H       16
# 4      FCS            1           1              1    75.0     H        5
#
#    value_2  value_3  value_4  ...  value_496  value_497  value_498  value_499  \
# 0      -38       10       43  ...         -5         10         10        -12
# 1      -49      137      -46  ...          6          5          6         -4
# 2       48      -13        8  ...        110        -52       -100         63
# 3      -11       22        4  ...          1         -1          4          4
# 4      -11       -4        2  ...          7          9        -33        -11
#
#    value_500  max_value  min_value  avg_value  p2p_value  peak_value
# 0         -6       3335      -2904    -12.574       6239      6239.0
# 1        -17       1794      -5425    -15.622       7219      7219.0
# 2         76       8664      -4533     22.256      13197     13197.0
# 3         -9       8603      -1911     19.398      10514     10514.0
# 4        -11       6241     -13943    -18.060      20184     20184.0
#
# [5 rows x 511 columns]

# %% [markdown]
# ## Add energy value

# %%
def add_energy_column(df, sampling_interval=4.5/500):
    """
    Adds a column representing the energy (numerical integration of absolute signal values)
    to characterize the strength of the recorded signal.

    Parameters:
    - df (pd.DataFrame): The DataFrame containing signal data.
    - sampling_interval (float): The estimated time step between consecutive signal samples.

    Returns:
    - pd.DataFrame: The DataFrame with the new 'energy' column.
    """
    # Signal data starts from column index 6
    signal_columns = df.columns[6:]

    # Compute energy using numerical integration (Riemann sum approximation)
    df['energy'] = df['peak_value'] * sampling_interval

    return df

# Example usage:
df_geophone = add_energy_column(df_geophone)
df_geophone.head()
# Out:
#   activity  fall_binary  distance_m  person_binary  weight floor  value_1  \
# 0      FCS            1           1              1    75.0     H       59
# 1      FCS            1           1              1    75.0     H      104
# 2      FCS            1           1              1    75.0     H      -11
# 3      FCS            1           1              1    75.0     H       16
# 4      FCS            1           1              1    75.0     H        5
#
#    value_2  value_3  value_4  ...  value_497  value_498  value_499  value_500  \
# 0      -38       10       43  ...         10         10        -12         -6
# 1      -49      137      -46  ...          5          6         -4        -17
# 2       48      -13        8  ...        -52       -100         63         76
# 3      -11       22        4  ...         -1          4          4         -9
# 4      -11       -4        2  ...          9        -33        -11        -11
#
#    max_value  min_value  avg_value  p2p_value  peak_value       energy
# 0       3335      -2904    -12.574       6239      6239.0   525.299166
# 1       1794      -5425    -15.622       7219      7219.0   522.986598
# 2       8664      -4533     22.256      13197     13197.0   849.935304
# 3       8603      -1911     19.398      10514     10514.0   649.317582
# 4       6241     -13943    -18.060      20184     20184.0  1130.094540
#
# [5 rows x 512 columns]
